# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# False

# %%
# Comprobamos las claves

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

openai = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT 4.1 nano, el modelo increíblemente económico.
MODEL = "llama3.2"

response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# La respuesta a la ecuación "2+2" es 4.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

MODEL = "llama3.2"

response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

print(response.choices[0].message.content)

print(question)
# Out:
# ¿Cuál es el límite superior de un número entero que se puede expresar como la suma de potencias de 3, multiplicado por potencias de 2 y sumados en orden decrecente?
# Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta.

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

MODEL = "llama3.2"

response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# ¿Cómo te diferenciarías entre un grupo de personas que han estado expuestas a 300 horas de educación formal durante su vida, pero solo han sido capaces de realizar una tarea matemática simple y precisa correctamente, sin matices o excepciones, mientras que another grupo, con las mismas horas de educación pero que nunca ha visto un problema como ese antes, requiere exactamente la misma cantidad de tiempo para resolverlo?

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# ¿Cómo te diferenciarías entre un grupo de personas que han estado expuestas a 300 horas de educación formal durante su vida, pero solo han sido capaces de realizar una tarea matemática simple y precisa correctamente, sin matices o excepciones, mientras que another grupo, con las mismas horas de educación pero que nunca ha visto un problema como ese antes, requiere exactamente la misma cantidad de tiempo para resolverlo?

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# Priemro creamos el mensaje

MODEL = "llama3.2"

question = "elije un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic."
messages = [{"role": "user", "content": question}]


response = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

business_idea = response.choices[0].message.content
print(business_idea)
# Y repetimos!
# Out:
# Excelente decisión considerar el uso de Agentic en un área de negocio prometa obtener beneficios significativos. Después de analizar diversas opciones, te presento algunas áreas de negocio potenciales donde el uso de Agentic podría valer la pena explorar:
#
# 1. **Servicio de consultoría**: Algunos expertos sugieren que el uso de IA en consultorías puede automatizar tareas administrativas y permitir un mejor análisis de datos, lo que puede llevar a mejores resultados en proyectos de consultoría.
#
# 2. **Marketing Digital**: En la actualidad, se analiza mucho mediante herramientas de inteligencia de negocios y análisis de comportamiento para ayudar marketing digitales a optimizar eficazmente sus estrategias.
#
# 3. **Finanzas personales**: Puede ayudar en diversas tareas como el seguimiento de gastos, planificación financiera y recomendaciones de inversión.
#
# 4. **Servicios de atención al cliente**: Las empresas que brindan servicios de atención al cliente pueden utilizar IA para automatizar algunas tarea automáticas y permitirles un mejor análisis de las necesidades del suscriptores.
#
# 5. **Análisis de datos medicinales**: El uso de inteligencia artificial se ha encontrado prometedor en el campo de la medicina, donde puede ayudar a identificar patrones en los registros médicos de los pacientes y proporcionar recomendaciones personalizadas.
#
# En cuanto a alguna área de negocio concreta, podrías considerar:
# - **Automatizar tareas administrativas**: Esto podría incluir la gestión de correos electrónicos, facturación digitalización de documentos, automatización de pagos, etc.
# -   **Optimización de procesos industriales**: Algunas empresas están explorando el uso de Agentic en la optimización de procesos industriales para reducir tiempos de producción y mejorar la eficiencia.
# - **Análisis de datos ambientales**: El Analitys IA puede ayudar a entender mejor los patrones del comportamiento de algunos organismos y así identificar nuevos métodos de mitigación de su impacto en el ambiente.
#
# Recuerda que antes de seleccionar una área de negocio, debes considerar factores como:
# -   **Competencia**: ¿Cuáles son las tendencias actuales en la industria?
# -   **Mercado potencial**: ¿Con qué clientes tiene el producto o servicio en mente?
# -   **Necesidades del mercado**: ¿Qué soluciones pueden ofrecer los productos o servicios?
# -   **Estabilidad comercial y recursos**: ¿Cuáles son las condiciones económicas?
# ¡Excelente decisión considerar el uso de Agentic en un área de negocio! Después de analizar las diferentes opciones, he seleccionado la **Automatización de procesos industriales** como el área de negocio potencial más prometedor para explorar el uso de Agentic.
#
# **Por qué esta opción?**
#
# 1.  **Crece con demanda:** La automatización industrial es un sector en crecimiento en las industrias contemporáneas. Se han tenido importantes avances significativos en este área.
# 2.  **Necesidades del mercado**: Las empresas industriales enfrentan muchos desafíos en cuanto a la productividad, el tiempo de producción y los costos totales, algunos de estos son: alta eficiencia, calidad en el producto y menor riesgo de fallas producciones.
# 3.  **Estabilidad comercial y recursos**: Aunque puede requerir inversión inicial ,con la ayuda del agentic, hay una mayor rentabilidad a largo plazo.
#
# **Vantajas de utilizar Agentic en automatización industrial**
#
# 1.  **Aumento de eficiencia**: Gracias al optimismo en las rutinas empresariales, pueden aumentar la productividad.
# 2.  **Mejora de la calidad**: El uso del agentic puede ayudar a detectar problemas y mejorar la calidad general de los productos producidos.
# 3.  **Reducción de costos**: Al automatizar tareas que antes necesitaban recursos humanos dedicados, las empresas pueden reducir sus costos productivos.
#
# **Desafíos y limitaciones**
#
# 1.  **Complejidad de los procesos industriales**: Es importante tener en cuenta que algunos procesos, como la producción de alimentos o productos farmacéuticos, pueden requerir una gestión más compleja debido a las regulaciones específicas.
# 2.  **Seguridad y privacidad**: La automatización industrial debe asegurarse de proteger la información sensible y garantizar la seguridad de los productos y procesos.
#
# **Conclusión**
#
# La automatización industrial ofrece un amplio espacio para las innovaciones y aplicaciones como Agentic, que pueden mejorar eficiencia y productividad.
# Entendido el problema y propuesta una solución completa:
#
# **Propuesta Solución: Integración de Agentic en la Automatización Industrial**
#
# **Objetivo**: Implementar una plataforma de automatización industrial utilizando Agentic para mejorar la eficiencia, calidad y reducir costos en los procesos industriales.
#
# **Estrategia de Implementación**
#
# 1.  **Análisis de necesidades específicas del negocio**: Evaluación detallada de las operaciones actuales, identifying áreas donde se pueda aplicar Agentic para mejorar la productividad, eficiencia y calidad.
# 2.  **Desarrollo de un plan de acción**: Creación de un kếzplan detaglado que priorice las inversiones en los procesos más importantes, asegurando la adaptabilidad al cambio y el crecimiento futuro del negocio.
# 3.  **Capacitación en el uso de Agentic**: Enseñanza formal y práctica para entender al máximo las herramientas ofrecidas por Agentic y cómo utilizarlas de manera efectiva.
#
# **Mejores Prácticas**
#
# - Comunicación fluida y oportuna entre todos los niveles del negocio (ingenieros, técnicos, personal administrativo) de manera que se mantenga una comunicación abierta para evitar errores.
#
# - Recopilación y análisis de datos pertinentes durante la automatización.

# %%
MODEL = "llama3.2"

orden = f"presenta un problema en el area de negocio {business_idea}, algo desafiante que pueda ser procipicio para una solucion con agentic."
messages = [{"role": "user", "content": orden}]

response2 = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

problematica = response2.choices[0].message.content
print(problematica)
# Out:
# Excelente decisión considerar el uso de Agentic en un área de negocio promete obtener beneficios significativos. Después de analizar diversas opciones, es fundamental evaluar los pros y contras de cada área de negocio potencial antes de tomar una decisión.
#
# Con base en las áreas de negocio que mencionaste, te propongo algunas observaciones y reflexiones sobre cuáles podrían ser más desafiantes:
#
# 1. **Servicio de consultoría**: Aunque el uso de Agentic puede automatizar tareas administrativas y mejorar el análisis de datos, es posible que las empresas sean cautelas al adoptar nuevas herramientas que pueden reemplazar a los expertos humanos en determinadas áreas.
#
# 2. **Marketing Digital**: La inteligencia artificial se utiliza cada vez más en marketing digital para optimizar estrategias, pero es importante tener en cuenta que la implementación exitosa requiere una cuidadosa evaluación de los alcances y limitaciones de las herramientas disponibles.
#
# 3. **Finanzas personales**: Aunque el uso de IA puede ayudar con tareas como seguimiento de gastos y planificación financiera, es posible que algunas personas no prefieran la automatización en áreas tan personales y requieran una interfaz más humana.
#
# 4. **Servicios de atención al cliente**: La automatización mediante AI puede ser útil para tareas como el manejo de sugerencias o preguntas frecuentes, pero es importante considerar la necesidad de humanos en áreas que requieren empatía, resolver problemas complejos y tomar decisiones basadas en los detalles específicos.
#
# 5. **Análisis de datos medicinales**: El uso de IA se ha encontrado prometedor en el campo médico, donde puede ayudar a identificar patrones en registros médicos de pacientes y proporcionar recomendaciones personalizadas. Sin embargo, la implementación requerirá una cuidadosa consideración ética, privacidad y seguridad.
#
# De las opciones que mencionaste para automatizar tareas administrativas, optimizar procesos industriales y realizar análisis de datos ambientales con Agentic en mind, se pueden destacar algunas desafiantes:
#
# *   **Automatizar tareas administrativas**: En algunas empresas, la inmensa cantidad de registros y documentos puede ser abrumadora. Por lo tanto, una herramientado como Agentic debe poder manejar un volumen significativo de datos con eficiencia.
#
# *   **Optimización de procesos industriales**: Las industrias que involucran largas cadenas de producción pueden tener procesos complejos y demandar horas o incluso segundos para hacer las pequeñas correcciones, con la posibilidad de que una herramienta como Agentic pueda reducir el tiempo de respuesta para optimizar los procedimientos a niveles más cercanos a una millisegundo.
#
# *   **Análisis de datos ambientales**: Al analizar grandes cantidades de datos en sistemas climáticos  y otros datos ambientales es posible que las computadoras requieran enormes cantidades de energía. La aplicación de una tecnolga como Agentic puede ayudar a acortar el consumo de energía.
#
# Para superar estos desafíos, debemos considerar cómo podemos abordar los siguientes aspectos:
#
# 1.  **Evaluación**: Esencialmente es fundamental evaluar las técnicas de Machine Learning y todas sus aplicaciones. Los que son capaces de realizar grandes tareas a una velocidad comparable con la humana, son los de mayor valor.
#
# 2.  **Flexibilidad:** No debes ser rígido a cuando se puede, donde se debe y donde el uso debe estar estrictamente definido. Debe poder funcionar bien en cualquier contexto requerido.
#
# 3.  Comunicación: Esto incluye la comunicación efectiva de la herramienta, como informes claros de resultados o recomendaciones precisas para mejorar.
#
# 4.  Adaptabilidad: Es crucial ser capaz de adaptarse a las condiciones cambiantes del mercado y de los usuarios.
#
# 5.  Estabilidad: Debe asegurarse que no haya problemas técnicos que afecten el rendimiento.
#
# Esta flexibilidad y eficiencia pueden ayudar al éxito exitoso en el uso de Agentic en un área de negocio.

# %%
MODEL = "llama3.2"

pregunta = f"Necesito que propongas una solucion a esta problemática: {problematica}"
messages = [{"role": "user", "content": pregunta}]

response3 = openai.chat.completions.create(
    model=MODEL,
    messages=messages
)

propuesta = response3.choices[0].message.content

print(propuesta)
# Out:
# Entiendo la preocupación por implementar tecnologías como Agentic para automatizar tareas administrativas, optimizar procesos industriales y realizar análisis de datos ambientales. A continuación, te presento algunas soluciones y estrategias que pueden ayudarte a abordar los desafíos mencionados:
#
# **Evaluación**
#
# 1.  Investiga las técnicas de Machine Learning más efectivas para tu problema específico.
# 2.  Analiza casos de éxito y estudios de caso relacionados con la implementación de Agentic en procesos similares.
#
# **Flexibilidad**
#
# 1.  Considera implementar una versión básica o personalizada del software para adaptarlo a tus necesidades específicas.
# 2.  Debería ser capaz de integrarse con herramientas y sistemas existentes en tu empresa, como bases de datos, sistemas de gestión de proyectos o software de marketing.
#
# **Comunicación**
#
# 1.  Implementa un sistema de alertas y notificaciones para informar sobre cambios significativos.
# 2.  Desarrolla un manual del usuario detallado y visualmente accesible que explique cómo funcionan las diferentes herramientas disponibles.
# 3.  Deberías integrarse al equipo de marketing, si es que lo haces, para entender mejor las necesidades del clientela.
#
# **Adaptabilidad**
#
# 1.  Establece un proceso claro de desarrollo continuo y actualización de la herramienta según sea necesario.
# 2.  Crea un plan de acción y comunica los resultados de manera clara al equipo.
#
# **Estabilidad**
#
# 1.  Implementa controles de seguridad robustos, como cifrado de datos y autenticación multifactorial.
# 2.  Realiza pruebas rigurosas antes del lanzamiento y mantén una revisión continua para asegurarse de que la herramienta está funcionando correctamente.
#
# Al seguir estas estrategias, podrás superar los desafíos mencionados y aprovechar al máximo el potencial de Agentic en tu empresa.
